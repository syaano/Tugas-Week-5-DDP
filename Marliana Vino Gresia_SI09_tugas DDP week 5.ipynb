# %%
my_list=["fazio","motor","yamaha","125cc"]
print(my_list)
# Out:
# ['fazio', 'motor', 'yamaha', '125cc']

# %%
my_list=["fazio","motor","yamaha","125cc"]
my_list.append("merah")
my_list.append("roda2")
my_list.append("22juta")
my_list.remove("motor")
print(my_list)
# Out:
# ['fazio', 'yamaha', '125cc', 'merah', 'roda2', '22juta']

# %%
ket = '''Selamat Datang di aplikasi menghitung luas bangun datar
Masukan pilihan :
1 = menghitung luas persegi
2 = menghitung luas lingkaran
3 = menghitung luas segitiga
silahkan pilih ?
'''
pilihan = input (ket)

match pilihan:
    case "1" :
        print ("kamu memilih 1 untuk menghitung luas persegi")
        sisi = int(input ("masukan sisi ?"))
        LPersegi = sisi * sisi
        print ("luas persegi adalah", LPersegi)
    case "2":
        print("kamu memilih 2 untuk menghitung luas lingkaran")
        r = int (input ("masukan jari-jari ?"))
        LLingkaran = 3.14 * r**2
        print ("Luas Lingkaran adalah", LLingkaran)
    case "3":
        print ("kamu memilih 3 untuk menghitung luas segitiga")
        alas = int(input ("masukan alas ?"))
        tinggi = int(input ("masukan tinggi ?"))
        LuasSegitiga = 0.5 * alas * tinggi
        print ("Luas Segitiga", LuasSegitiga)
    case _:
        print ("pilihan  salah")
